# %% [markdown]
# ## 2. 3Sum LC 15 – 3Sum | Medium | * | Google: G1 | Microsoft: M2
#
# Given an integer array nums, return all the triplets [nums[i], nums[j], nums[k]] such that i != j, i != k, and j != k, and nums[i] + nums[j] + nums[k] == 0.
#
# Notice that the solution set must not contain duplicate triplets.
#
# Example 1:
#
# Input: nums = [-1,0,1,2,-1,-4]
# Output: [[-1,-1,2],[-1,0,1]]
# Explanation:
# nums[0] + nums[1] + nums[2] = (-1) + 0 + 1 = 0.
# nums[1] + nums[2] + nums[4] = 0 + 1 + (-1) = 0.
# nums[0] + nums[3] + nums[4] = (-1) + 2 + (-1) = 0.
# The distinct triplets are [-1,0,1] and [-1,-1,2].
# Notice that the order of the output and the order of the triplets does not matter.
# Example 2:
#
# Input: nums = [0,1,1]
# Output: []
# Explanation: The only possible triplet does not sum up to 0.
# Example 3:
#
# Input: nums = [0,0,0]
# Output: [[0,0,0]]
# Explanation: The only possible triplet sums up to 0.
#
# Constraints:
#
# 3 <= nums.length <= 3000
# -105 <= nums[i] <= 105

# %% [markdown]
# Brute Force Approach (O(n³))
# ✔ Idea
#
# Check every possible triplet (i, j, k) and see if:
#
# nums[i] + nums[j] + nums[k] == 0
#
# ❗ Issues
#
# Very slow for large input (n³).
#
# Needs a way to avoid duplicates.

# %%
def threeSum_bruteforce(nums):
    n = len(nums)
    result = set()  # use set to avoid duplicates

    for i in range(n):
        for j in range(i + 1, n):
            for k in range(j + 1, n):
                if nums[i] + nums[j] + nums[k] == 0:
                    triplet = tuple(sorted([nums[i], nums[j], nums[k]]))
                    result.add(triplet)

    return [list(t) for t in result]

# %% [markdown]
# 2. Optimized Approach — Sorting + Two Pointers (O(n²))
#
# Sort the array.
#
# Fix one number → convert the rest into a two-sum problem.
#
# Use two pointers (left, right) to find pairs that sum to -nums[i].
#
# Skip duplicates properly.

# %%
def threeSum(nums):
    nums.sort()
    result = []
    n = len(nums)

    for i in range(n):
        # Skip duplicate first elements
        if i > 0 and nums[i] == nums[i - 1]:
            continue

        left, right = i + 1, n - 1

        while left < right:
            s = nums[i] + nums[left] + nums[right]

            if s == 0:
                result.append([nums[i], nums[left], nums[right]])

                # Skip duplicate left
                while left < right and nums[left] == nums[left + 1]:
                    left += 1
                # Skip duplicate right
                while left < right and nums[right] == nums[right - 1]:
                    right -= 1

                left += 1
                right -= 1

            elif s < 0:
                left += 1
            else:
                right -= 1

    return result
